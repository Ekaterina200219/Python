# %%
import scipy.integrate as sp

# %%
import numpy as np
# from decimal import Decimal
# decimal.getcontext().prec=4

# %%
func = lambda x: np.sin(x) * x ** 2

# %%
f_integrated = sp.quad(func, 0, 3)
print(f_integrated)
# Out:
# (5.7766675245623205, 6.413389291373496e-14)

# %%
N = 1000

# %%
x = np.random.random(N)*3
y = np.random.random(N)*4

# %%
# (list(map(func, x)) < y).astype(int)

# %%
import matplotlib.pyplot as plt

# %%
x_ = sorted(x)
x_ = list(map(func, x))

# %%
x_ = np.linspace(0, 3, N)
# print(x_)
y_ = np.sin(x_) * x_**2 
# print(y_)

# %%
plt.figure(figsize=(15, 10))
plt.scatter(x, y_)
plt.grid()
a = 3
b = 4
plt.axis([0, a, 0, b]) # Range 0 <= x <= 3 AND 0 <= y < = 4
plt.plot(x_, y_)
plt.show()

# %%
import scipy.integrate as sp
from scipy import random
import matplotlib.pyplot as plt
import numpy as np
import math as m
func = lambda x: np.sin(x) * x ** 2

# %%
n=10000 
k=0 # Счетчик
a=0 # минимум x
b=3 # максимум x
f_min=0 # минимум функции
f_max=4 # максимум функции


f_integrated=sp.quad(func,a,b) 
print(f'Значение существующей функции = {f_integrated}')
# Out:
# Значение существующей функции = (5.7766675245623205, 6.413389291373496e-14)

# %%
z = [] 
for i in range (1,n):
    x=a+random.random()*(b-a) 
    y=f_min+random.random()*(f_max-f_min)
    if y<f(x): 
        k+=1 
        z.append(x) 
s=(b-a)*(f_max-f_min)*k/n
print(f'Вычисленное значение = {s}')
result = abs(s - f_integrated[0])
print(f'Разница между вычисленным значением и существующей функцией = {result}')
plt.figure(figsize=(10, 10))
plt.hist(z,bins=50,ec='red',color='blue')
# Out:
# Вычисленное значение = 5.8056
# Разница между вычисленным значением и существующей функцией = 0.028932475437679628
# (array([  6.,   4.,   4.,   6.,   5.,   7.,  12.,  15.,  24.,  22.,  29.,
#          28.,  35.,  40.,  55.,  56.,  75.,  68.,  55.,  77.,  93.,  98.,
#          98., 122., 101., 135., 136., 158., 137., 146., 147., 173., 161.,
#         173., 137., 171., 160., 197., 188., 180., 178., 161., 158., 152.,
#         146., 135., 105., 111.,  86.,  72.]),
#  array([0.3296355 , 0.38303883, 0.43644216, 0.48984548, 0.54324881,
#         0.59665214, 0.65005546, 0.70345879, 0.75686212, 0.81026545,
#         0.86366877, 0.9170721 , 0.97047543, 1.02387875, 1.07728208,
#         1.13068541, 1.18408873, 1.23749206, 1.29089539, 1.34429872,
#         1.39770204, 1.45110537, 1.5045087 , 1.55791202, 1.61131535,
#         1.66471868, 1.718122  , 1.77152533, 1.82492866, 1.87833199,
#         1.93173531, 1.98513864, 2.03854197, 2.09194529, 2.14534862,
# ...
