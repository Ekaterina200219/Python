# %%
import numpy as np
import pandas as pd
import networkx as nx

# %%
G = nx.DiGraph()
G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(1, 4)
G.add_edge(2, 8)
G.add_edge(2, 4)
G.add_edge(3, 4)
G.add_edge(3, 5)
G.add_edge(3, 6)
G.add_edge(4, 7)
G.add_edge(4, 5)
G.add_edge(5, 6)
G.add_edge(6, 12)
G.add_edge(6, 14)
G.add_edge(7, 8)
G.add_edge(7, 12)
G.add_edge(8, 9)
G.add_edge(8, 10)
G.add_edge(9, 10)
G.add_edge(9, 11)
G.add_edge(10, 11)
G.add_edge(11, 12)
G.add_edge(11, 13)
G.add_edge(12, 13)
G.add_edge(12, 14)
G.add_edge(12, 15)
G.add_edge(13, 15)
G.add_edge(14, 15)

nx.draw_circular(G,
         node_color='red',
         node_size=1000,
         with_labels=True)

# %%
#ребра с весами 
weight = {('1', '2', 10),
          ('1', '3', 12),
          ('1', '4', 13),
          ('2', '8', 12),
          ('2', '4', 10),
          ('3', '4', 4),
          ('3', '5', 6),
          ('3', '6', 8),
          ('4', '7', 7),
          ('4', '5', 5),
          ('5', '6', 4),
          ('6', '12', 3),
          ('6', '14', 4),
          ('7', '8', 7),
          ('7', '12', 9),
          ('8', '9', 8),
          ('8', '10', 5),
          ('9', '10', 6),
          ('9', '11', 3),
          ('10', '11', 7),
          ('11', '12', 6),
          ('11', '13', 4),
          ('12', '13', 5),
          ('12', '14', 8),
          ('12', '15', 10),
          ('13', '15', 10),
          ('14', '15', 23)}

G.add_weighted_edges_from(weight)

# %%
nx.draw_circular(G,
         node_color='red',
         node_size=1000,
         with_labels=True)

# %%
weight_list = [10, 12, 13, 12, 10, 4, 6, 8, 7, 5, 4, 3, 4, 7, 9, 8, 5, 6, 3, 7, 6, 4, 5, 8, 10, 10, 23]

for i in range(26):
    t_rn1 = 0
    t_rn2 = 0
    t_rn3 = 0
    t_rn4 = 0 + weight_list[0]
    t_rn5 = 0 + weight_list[0]
    t_rn6 = 0 + weight_list[1]
    t_rn7 = 0 + weight_list[1]
    t_rn8 = 0 + weight_list[1]
    t_rn9 = weight_list[0] + t_rn4
    t_rn10 = weight_list[0] + t_rn4
    t_rn11 = t_rn10 + weight_list[9]
    t_rn12 = t_rn9 + weight_list[14]
    t_rn13 = t_rn9 + weight_list[14]
    t_rn14 = t_rn10 + weight_list[8]
    t_rn15 = t_rn9 + weight_list[8]
    t_rn16 = t_rn15 + weight_list[13]
    t_rn17 = t_rn15 + weight_list[13]
    t_rn18 = t_rn17 + weight_list[15]
    t_rn19 = t_rn17 + weight_list[15]
    t_rn20 = t_rn19 + weight_list[17]
    t_rn21 = t_rn20 + weight_list[19]
    t_rn22 = t_rn20 + weight_list[19]
    t_rn23 = t_rn22 + weight_list[20]
    t_rn24 = t_rn22 + weight_list[20]
    t_rn25 = t_rn22 + weight_list[20]
    t_rn26 = t_rn25 + weight_list[22]
    t_rn27 = t_rn25 + weight_list[23]
    
print(f"Р.Н. #1: {t_rn1}")
print(f"Р.Н. #2: {t_rn2}")
print(f"Р.Н. #3: {t_rn3}")
print(f"Р.Н. #4: {t_rn4}")
print(f"Р.Н. #5: {t_rn5}")
print(f"Р.Н. #6: {t_rn6}")
print(f"Р.Н. #7: {t_rn7}")
print(f"Р.Н. #8: {t_rn8}")
print(f"Р.Н. #9: {t_rn9}")
print(f"Р.Н. #10: {t_rn10}")
print(f"Р.Н. #11: {t_rn11}")
print(f"Р.Н. #12: {t_rn12}")
print(f"Р.Н. #13: {t_rn13}")
print(f"Р.Н. #14: {t_rn14}")
print(f"Р.Н. #15: {t_rn15}")
print(f"Р.Н. #16: {t_rn16}")
print(f"Р.Н. #17: {t_rn17}")
print(f"Р.Н. #18: {t_rn18}")
print(f"Р.Н. #19: {t_rn19}")
print(f"Р.Н. #20: {t_rn20}")
print(f"Р.Н. #21: {t_rn21}")
print(f"Р.Н. #22: {t_rn22}")
print(f"Р.Н. #23: {t_rn23}")
print(f"Р.Н. #24: {t_rn24}")
print(f"Р.Н. #25: {t_rn25}")
print(f"Р.Н. #26: {t_rn26}")
print(f"Р.Н. #27: {t_rn27}")
# Out:
# Р.Н. #1: 0
# Р.Н. #2: 0
# Р.Н. #3: 0
# Р.Н. #4: 10
# Р.Н. #5: 10
# Р.Н. #6: 12
# Р.Н. #7: 12
# Р.Н. #8: 12
# Р.Н. #9: 20
# Р.Н. #10: 20
# Р.Н. #11: 25
# Р.Н. #12: 29
# Р.Н. #13: 29
# Р.Н. #14: 27
# Р.Н. #15: 27
# Р.Н. #16: 34
# Р.Н. #17: 34
# Р.Н. #18: 42
# Р.Н. #19: 42
# Р.Н. #20: 48
# Р.Н. #21: 55
# Р.Н. #22: 55
# Р.Н. #23: 61
# Р.Н. #24: 61
# Р.Н. #25: 61
# Р.Н. #26: 66
# Р.Н. #27: 69

# %%
for i in range(26):
    t_ro1 = t_rn1 + weight_list[0]
    t_ro2 = t_rn2 + weight_list[1]
    t_ro3 = t_rn3 + weight_list[2]
    t_ro4 = t_rn4 + weight_list[3]
    t_ro5 = t_rn5 + weight_list[4]
    t_ro6 = t_rn6 + weight_list[5]
    t_ro7 = t_rn7 + weight_list[6]
    t_ro8 = t_rn8 + weight_list[7]
    t_ro9 = t_rn9 + weight_list[8]
    t_ro10 = t_rn10 + weight_list[9]
    t_ro11 = t_rn11 + weight_list[10]
    t_ro12 = t_rn12 + weight_list[11]
    t_ro13 = t_rn13 + weight_list[12]
    t_ro14 = t_rn14 + weight_list[13]
    t_ro15 = t_rn15 + weight_list[14]
    t_ro16 = t_rn16 + weight_list[15]
    t_ro17 = t_rn17 + weight_list[16]
    t_ro18 = t_rn18 + weight_list[17]
    t_ro19 = t_rn19 + weight_list[18]
    t_ro20 = t_rn20 + weight_list[19]
    t_ro21 = t_rn21 + weight_list[20]
    t_ro22 = t_rn22 + weight_list[21]
    t_ro23 = t_rn23 + weight_list[22]
    t_ro24 = t_rn24 + weight_list[23]
    t_ro25 = t_rn25 + weight_list[24]
    t_ro26 = t_rn26 + weight_list[25]
    t_ro27 = t_rn27 + weight_list[26]
    
print(f"Р.О. #1: {t_ro1}")
print(f"Р.О. #2: {t_ro2}")
print(f"Р.О. #3: {t_ro3}")
print(f"Р.О. #4: {t_ro4}")
print(f"Р.О. #5: {t_ro5}")
print(f"Р.О. #6: {t_ro6}")
print(f"Р.О. #7: {t_ro7}")
print(f"Р.О. #8: {t_ro8}")
print(f"Р.О. #9: {t_ro9}")
print(f"Р.О. #10: {t_ro10}")
print(f"Р.О. #11: {t_ro11}")
print(f"Р.О. #12: {t_ro12}")
print(f"Р.О. #13: {t_ro13}")
print(f"Р.О. #14: {t_ro14}")
print(f"Р.О. #15: {t_ro15}")
print(f"Р.О. #16: {t_ro16}")
print(f"Р.О. #17: {t_ro17}")
print(f"Р.О. #18: {t_ro18}")
print(f"Р.О. #19: {t_ro19}")
print(f"Р.О. #20: {t_ro20}")
print(f"Р.О. #21: {t_ro21}")
print(f"Р.О. #22: {t_ro22}")
print(f"Р.О. #23: {t_ro23}")
print(f"Р.О. #24: {t_ro24}")
print(f"Р.О. #25: {t_ro25}")
print(f"Р.О. #26: {t_ro26}")
print(f"Р.О. #27: {t_ro27}")
# Out:
# Р.О. #1: 10
# Р.О. #2: 12
# Р.О. #3: 13
# Р.О. #4: 22
# Р.О. #5: 20
# Р.О. #6: 16
# Р.О. #7: 18
# Р.О. #8: 20
# Р.О. #9: 27
# Р.О. #10: 25
# Р.О. #11: 29
# Р.О. #12: 32
# Р.О. #13: 33
# Р.О. #14: 34
# Р.О. #15: 36
# Р.О. #16: 42
# Р.О. #17: 39
# Р.О. #18: 48
# Р.О. #19: 45
# Р.О. #20: 55
# Р.О. #21: 61
# Р.О. #22: 59
# Р.О. #23: 66
# Р.О. #24: 69
# Р.О. #25: 71
# Р.О. #26: 76
# Р.О. #27: 92

# %%
for i in range(26):
    t_pn1 = t_rn4 - weight_list[0] 
    t_pn2 = (t_rn6 + weight_list[5]) - weight_list[1] 
    t_pn3 = t_rn9 - weight_list[2] 
    t_pn4 = (t_rn14 + weight_list[13]) - weight_list[3] 
    t_pn5 = t_rn9 - weight_list[4] 
    t_pn6 = t_rn9 - weight_list[5] 
    t_pn7 = (t_rn23 - weight_list[8]) - weight_list[6] 
    t_pn8 = (t_rn21 + weight_list[18]) - weight_list[7] 
    t_pn9 = t_rn14 - weight_list[8] 
    t_pn10 = (t_rn23 - weight_list[8]) - weight_list[9] 
    t_pn11 = (t_rn21 + weight_list[18]) - weight_list[10] 
    t_pn12 = t_rn23 - weight_list[11] 
    t_pn13 = t_rn27 - weight_list[12] 
    t_pn14 = t_rn16 - weight_list[13] 
    t_pn15 = t_rn23 - weight_list[14] 
    t_pn16 = t_rn18 - weight_list[15] 
    t_pn17 = t_rn20 - weight_list[16] 
    t_pn18 = t_rn20 - weight_list[17] 
    t_pn19 = t_rn21 - weight_list[18] 
    t_pn20 = t_rn21 - weight_list[19] 
    t_pn21 = t_rn23 - weight_list[20] 
    t_pn22 = (t_rn27 + weight_list[2]) - weight_list[21] 
    t_pn23 = (t_rn27 + weight_list[2]) - weight_list[22] 
    t_pn24 = t_rn27 - weight_list[23] 
    t_pn25 = (t_rn27 + weight_list[26]) - weight_list[24] 
    t_pn26 = (t_rn27 + weight_list[26]) - weight_list[25]
    t_pn27 = (t_rn27 + weight_list[26]) - weight_list[26]
    
print(f"П.Н. #1: {t_pn1}")
print(f"П.Н. #2: {t_pn2}")
print(f"П.Н. #3: {t_pn3}")
print(f"П.Н. #4: {t_pn4}")
print(f"П.Н. #5: {t_pn5}")
print(f"П.Н. #6: {t_pn6}")
print(f"П.Н. #7: {t_pn7}")
print(f"П.Н. #8: {t_pn8}")
print(f"П.Н. #9: {t_pn9}")
print(f"П.Н. #10: {t_pn10}")
print(f"П.Н. #11: {t_pn11}")
print(f"П.Н. #12: {t_pn12}")
print(f"П.Н. #13: {t_pn13}")
print(f"П.Н. #14: {t_pn14}")
print(f"П.Н. #15: {t_pn15}")
print(f"П.Н. #16: {t_pn16}")
print(f"П.Н. #17: {t_pn17}")
print(f"П.Н. #18: {t_pn18}")
print(f"П.Н. #19: {t_pn19}")
print(f"П.Н. #20: {t_pn20}")
print(f"П.Н. #21: {t_pn21}")
print(f"П.Н. #22: {t_pn22}")
print(f"П.Н. #23: {t_pn23}")
print(f"П.Н. #24: {t_pn24}")
print(f"П.Н. #25: {t_pn25}")
print(f"П.Н. #26: {t_pn26}")
print(f"П.Н. #27: {t_pn27}")
# Out:
# П.Н. #1: 0
# П.Н. #2: 4
# П.Н. #3: 7
# П.Н. #4: 22
# П.Н. #5: 10
# П.Н. #6: 16
# П.Н. #7: 48
# П.Н. #8: 50
# П.Н. #9: 20
# П.Н. #10: 49
# П.Н. #11: 54
# П.Н. #12: 58
# П.Н. #13: 65
# П.Н. #14: 27
# П.Н. #15: 52
# П.Н. #16: 34
# П.Н. #17: 43
# П.Н. #18: 42
# П.Н. #19: 52
# П.Н. #20: 48
# П.Н. #21: 55
# П.Н. #22: 78
# П.Н. #23: 77
# П.Н. #24: 61
# П.Н. #25: 82
# П.Н. #26: 82
# П.Н. #27: 69

# %%
for i in range(26):
    t_po1 = t_rn9 - weight_list[4]
    t_po2 = t_rn9 - weight_list[5] 
    t_po3 = t_rn14 - weight_list[8]
    t_po4 = t_rn18 - weight_list[15]
    t_po5 = t_rn14 - weight_list[8] 
    t_po6 = t_rn14 - weight_list[8]
    t_po7 = (t_rn21 + weight_list[18]) - weight_list[10]
    t_po8 = t_rn23 - weight_list[11]
    t_po9 = t_rn16 - weight_list[13]
    t_po10 = (t_rn21 + weight_list[18]) - weight_list[10]
    t_po11 = t_rn23 - weight_list[11]
    t_po12 = t_rn27 - weight_list[23] 
    t_po13 = (t_rn27 + weight_list[26]) - weight_list[26]
    t_po14 = t_rn18 - weight_list[15]
    t_po15 = t_rn27 - weight_list[23]
    t_po16 = t_rn20 - weight_list[17] 
    t_po17 = t_rn21 - weight_list[19] 
    t_po18 = t_rn21 - weight_list[19] 
    t_po19 = t_rn23 - weight_list[20] 
    t_po20 = t_rn23 - weight_list[20] 
    t_po21 = t_rn27 - weight_list[23] 
    t_po22 = (t_rn27 + weight_list[26]) - weight_list[24] 
    t_po23 = (t_rn27 + weight_list[26]) - weight_list[24]
    t_po24 = (t_rn27 + weight_list[26]) - weight_list[26] 
    t_po25 = t_rn27 + weight_list[26]
    t_po26 = t_rn27 + weight_list[26]
    t_po27 = t_rn27 + weight_list[26]
    
print(f"П.О. #1: {t_po1}")
print(f"П.О. #2: {t_po2}")
print(f"П.О. #3: {t_po3}")
print(f"П.О. #4: {t_po4}")
print(f"П.О. #5: {t_po5}")
print(f"П.О. #6: {t_po6}")
print(f"П.О. #7: {t_po7}")
print(f"П.О. #8: {t_po8}")
print(f"П.О. #9: {t_po9}")
print(f"П.О. #10: {t_po10}")
print(f"П.О. #11: {t_po11}")
print(f"П.О. #12: {t_po12}")
print(f"П.О. #13: {t_po13}")
print(f"П.О. #14: {t_po14}")
print(f"П.О. #15: {t_po15}")
print(f"П.О. #16: {t_po16}")
print(f"П.О. #17: {t_po17}")
print(f"П.О. #18: {t_po18}")
print(f"П.О. #19: {t_po19}")
print(f"П.О. #20: {t_po20}")
print(f"П.О. #21: {t_po21}")
print(f"П.О. #22: {t_po22}")
print(f"П.О. #23: {t_po23}")
print(f"П.О. #24: {t_po24}")
print(f"П.О. #25: {t_po25}")
print(f"П.О. #26: {t_po26}")
print(f"П.О. #27: {t_po27}")
# Out:
# П.О. #1: 10
# П.О. #2: 16
# П.О. #3: 20
# П.О. #4: 34
# П.О. #5: 20
# П.О. #6: 20
# П.О. #7: 54
# П.О. #8: 58
# П.О. #9: 27
# П.О. #10: 54
# П.О. #11: 58
# П.О. #12: 61
# П.О. #13: 69
# П.О. #14: 34
# П.О. #15: 61
# П.О. #16: 42
# П.О. #17: 48
# П.О. #18: 48
# П.О. #19: 55
# П.О. #20: 55
# П.О. #21: 61
# П.О. #22: 82
# П.О. #23: 82
# П.О. #24: 69
# П.О. #25: 92
# П.О. #26: 92
# П.О. #27: 92

# %%
for i in range(26):
    reserve1 = t_po1 - t_ro1
    reserve2 = t_po2 - t_ro2
    reserve3 = t_po3 - t_ro3
    reserve4 = t_po4 - t_ro4
    reserve5 = t_po5 - t_ro5
    reserve6 = t_po6 - t_ro6
    reserve7 = t_po7 - t_ro7
    reserve8 = t_po8 - t_ro8
    reserve9 = t_po9 - t_ro9
    reserve10 = t_po10 - t_ro10
    reserve11 = t_po11 - t_ro11
    reserve12 = t_po12 - t_ro12
    reserve13 = t_po13 - t_ro13
    reserve14 = t_po14 - t_ro14
    reserve15 = t_po15 - t_ro15
    reserve16 = t_po16 - t_ro16 
    reserve17 = t_po17 - t_ro17
    reserve18 = t_po18 - t_ro18
    reserve19 = t_po19 - t_ro19
    reserve20 = t_po20 - t_ro20
    reserve21 = t_po21 - t_ro21
    reserve22 = t_po22 - t_ro22
    reserve23 = t_po23 - t_ro23
    reserve24 = t_po24 - t_ro24
    reserve25 = t_po25 - t_ro25
    reserve26 = t_po26 - t_ro26
    reserve27 = t_po27 - t_ro27
    
print(f"Резерв #1: {reserve1}")
print(f"Резерв #2: {reserve2}")
print(f"Резерв #3: {reserve3}")
print(f"Резерв #4: {reserve4}")
print(f"Резерв #5: {reserve5}")
print(f"Резерв #6: {reserve6}")
print(f"Резерв #7: {reserve7}")
print(f"Резерв #8: {reserve8}")
print(f"Резерв #9: {reserve9}")
print(f"Резерв #10: {reserve10}")
print(f"Резерв #11: {reserve11}")
print(f"Резерв #12: {reserve12}")
print(f"Резерв #13: {reserve13}")
print(f"Резерв #14: {reserve14}")
print(f"Резерв #15: {reserve15}")
print(f"Резерв #16: {reserve16}")
print(f"Резерв #17: {reserve17}")
print(f"Резерв #18: {reserve18}")
print(f"Резерв #19: {reserve19}")
print(f"Резерв #20: {reserve20}")
print(f"Резерв #21: {reserve21}")
print(f"Резерв #22: {reserve22}")
print(f"Резерв #23: {reserve23}")
print(f"Резерв #24: {reserve24}")
print(f"Резерв #25: {reserve25}")
print(f"Резерв #26: {reserve26}")
print(f"Резерв #27: {reserve27}")
# Out:
# Резерв #1: 0
# Резерв #2: 4
# Резерв #3: 7
# Резерв #4: 12
# Резерв #5: 0
# Резерв #6: 4
# Резерв #7: 36
# Резерв #8: 38
# Резерв #9: 0
# Резерв #10: 29
# Резерв #11: 29
# Резерв #12: 29
# Резерв #13: 36
# Резерв #14: 0
# Резерв #15: 25
# Резерв #16: 0
# Резерв #17: 9
# Резерв #18: 0
# Резерв #19: 10
# Резерв #20: 0
# Резерв #21: 0
# Резерв #22: 23
# Резерв #23: 16
# Резерв #24: 0
# Резерв #25: 21
# Резерв #26: 16
# Резерв #27: 0

# %%
time_indicators = pd.DataFrame({'Работа': ['1-2', '1-3', '1-4', '2-8', '2-4', '3-4', '3-5', '3-6', '4-7', '4-5', '5-6', '6-12', '6-14', '7-8', '7-12', '8-9', '8-10', '9-10', '9-11', '10-11', '11-12', '11-13', '12-13', '12-14', '12-15', '13-15', '14-15'],
                                'days': [10, 12, 13, 12, 10, 4, 6, 8, 7, 5, 4, 3, 4, 7, 9, 8, 5, 6, 3, 7, 6, 4, 5, 8, 10, 10, 23],
                                'R.N.': [0, 0, 0, 10, 10, 12, 12, 12, 20, 20, 25, 29, 29, 27, 27, 34, 34, 42, 42, 48, 55, 55, 61, 61, 61, 66, 69],
                                'R.O.': [10, 12, 13, 22, 20, 16, 18, 20, 27, 25, 29, 32, 33, 34, 36, 42, 39, 48, 45, 55, 61, 59, 66, 69, 71, 76, 92],
                                'P.N.': [0, 4, 7, 22, 10, 16, 48, 50, 20, 49, 54, 58, 65, 27, 52, 34, 43, 42, 52, 48, 55, 78, 77, 61, 82, 82, 69],
                                'P.O.': [10, 16, 20, 34, 20, 20, 54, 58, 27, 54, 58, 61, 69, 34, 61, 42, 48, 48, 55, 55, 61, 82, 82, 69, 92, 92, 92],
                                'Reserve': [0, 4, 7, 12, 0, 4, 36, 38, 0, 29, 29, 29, 36, 0, 25, 0, 9, 0, 10, 0, 0, 23, 16, 0, 21, 16, 0]})

# %%
time_indicators
# Out:
#    Работа  days  R.N.  R.O.  P.N.  P.O.  Reserve
# 0     1-2    10     0    10     0    10        0
# 1     1-3    12     0    12     4    16        4
# 2     1-4    13     0    13     7    20        7
# 3     2-8    12    10    22    22    34       12
# 4     2-4    10    10    20    10    20        0
# 5     3-4     4    12    16    16    20        4
# 6     3-5     6    12    18    48    54       36
# 7     3-6     8    12    20    50    58       38
# 8     4-7     7    20    27    20    27        0
# 9     4-5     5    20    25    49    54       29
# 10    5-6     4    25    29    54    58       29
# 11   6-12     3    29    32    58    61       29
# 12   6-14     4    29    33    65    69       36
# 13    7-8     7    27    34    27    34        0
# 14   7-12     9    27    36    52    61       25
# 15    8-9     8    34    42    34    42        0
# 16   8-10     5    34    39    43    48        9
# 17   9-10     6    42    48    42    48        0
# ...

# %%
critical_path = 0
reserve_list = [0, 4, 7, 12, 0, 4, 36, 38, 0, 29, 29, 29, 36, 0, 25, 0, 9, 0, 10, 0, 0, 23, 16, 0, 21, 16, 0]

for i in range(len(reserve_list)):
    if reserve_list[i] == 0:
        critical_path = critical_path + weight_list[i]
    else:
        critical_path = critical_path


print(f"Критический путь равен = {critical_path}")
# Out:
# Критический путь равен = 92
