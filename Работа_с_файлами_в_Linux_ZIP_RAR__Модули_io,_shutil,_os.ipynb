# %% [markdown]
# ###Полезные источники
# - Создание и распаковка ZIP-архивов
#
# https://vps.ua/wiki/creating-unpacking-files-linux/#a-5
#
# - Методы получения справки из системы
#
# http://www.linuxcookbook.ru/books/slackbook/help-system.html
#
# - Получение списка файлов в директории на Python
#
# https://www.severcart.ru/blog/all/list_direcory_content_with_python/

# %% [markdown]
# ###Получение справочной информации

# %%
import io

# %% [markdown]
# io — Core tools for working with streams
#
# https://docs.python.org/3.6/library/io.html

# %%
help(io)
# Out:
# Help on module io:
#
# NAME
#     io
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/io.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     The io module provides the Python interfaces to stream handling. The
#     builtin open function is defined in this module.
#
#     At the top of the I/O hierarchy is the abstract base class IOBase. It
#     defines the basic interface to a stream. Note, however, that there is no
#     separation between reading and writing to streams; implementations are
#     allowed to raise an OSError if they do not support a given operation.
#
#     Extending IOBase is RawIOBase which deals simply with the reading and
# ...

# %%
 import os

# %% [markdown]
# os MODULE REFERENCE
#     https://docs.python.org/3.6/library/os

# %%
 import shutil

# %%
# !zip --help
# Out:
# Copyright (c) 1990-2008 Info-ZIP - Type 'zip "-L"' for software license.
# Zip 3.0 (July 5th 2008). Usage:
# zip [-options] [-b path] [-t mmddyyyy] [-n suffixes] [zipfile list] [-xi list]
#   The default action is to add or replace zipfile entries from list, which
#   can include the special name - to compress standard input.
#   If zipfile and list are omitted, zip compresses stdin to stdout.
#   -f   freshen: only changed files  -u   update: only changed or new files
#   -d   delete entries in zipfile    -m   move into zipfile (delete OS files)
#   -r   recurse into directories     -j   junk (don't record) directory names
#   -0   store only                   -l   convert LF to CR LF (-ll CR LF to LF)
#   -1   compress faster              -9   compress better
#   -q   quiet operation              -v   verbose operation/print version info
#   -c   add one-line comments        -z   add zipfile comment
#   -@   read names from stdin        -o   make zipfile as old as latest entry
# ...

# %% [markdown]
# Команда man (сокращение от “manual” -- руководство, справочник) это традиционная форма интерактивной документации в операционных системах Unix и Linux.

# %%
# !man zip
# Out:
# This system has been minimized by removing packages and content that are
# not required on a system that users do not log into.
#
# To restore this content, including manpages, you can run the 'unminimize'
# command. You will still need to ensure the 'man-db' package is installed.

# %%
# !whatis zip
# Out:
# zip (1)              - package and compress (archive) files

# %%
# !whatis cp
# Out:
# cp (1posix)          - copy files

# %%
# !whatis mv
# Out:
# mv (1posix)          - move files

# %% [markdown]
# ###Необходимые ресурсы

# %%
import os
from google.colab import files
import zipfile
import io, shutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Подключим Google диск через Mount Drive (см. слева)

# %%
# проверим подключение Google диска
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# #### Копируем файл с Google диска

# %%
# скопируем файл с Google диска
# !cp '/content/drive/MyDrive/Dolphin.zip' Dolphin.zip

# %%
# проверим загрузку файла
# !ls
# Out:
# Dolphin.zip  drive  sample_data

# %% [markdown]
# ###Создание директории

# %%
# создадим директорию для распаковки архива
# !mkdir data

# %% [markdown]
# ###Распаковка архива

# %%
# распакуем архив в директорию data
# !unzip -d data Dolphin.zip
# Out:
# Archive:  Dolphin.zip
#    creating: data/Dolphin/
#   inflating: data/Dolphin/10004986625_0f786ab86b_b.jpg
#   inflating: data/Dolphin/10024981276_65f3d41599_b.jpg
#   inflating: data/Dolphin/10080987554_27d23b7ca3_o.jpg
#   inflating: data/Dolphin/10132691013_8d9e263177_o.jpg
#   inflating: data/Dolphin/10153182025_b69bef91f0_b.jpg
#   inflating: data/Dolphin/10162596245_7b2714189c_b.jpg
#   inflating: data/Dolphin/10224905906_94231b2cd6_b.jpg
#   inflating: data/Dolphin/10242419916_57b7581c4e_o.jpg
#   inflating: data/Dolphin/10322994536_8bfd6decf1_b.jpg
#   inflating: data/Dolphin/10325328745_bcc475b493_o.jpg
#   inflating: data/Dolphin/10329978914_923a9af626_o.png
#   inflating: data/Dolphin/10426410553_2b4c9167f0_b.jpg
#   inflating: data/Dolphin/10446046326_b23d79bcc8_o.jpg
#   inflating: data/Dolphin/10501809364_d8135e034f_o.jpg
#   inflating: data/Dolphin/10730556235_0ccecfff6c_o.jpg
#   inflating: data/Dolphin/10792745504_ce6c3cabc1_o.jpg
# ...

# %%
# посмотрим содержимое папки data
print(os.listdir('data'))
# Out:
# ['Dolphin']

# %%
# поместим список файлов в переменную
file_list = os.listdir('data')
file_list
# Out:
# ['Dolphin']

# %%
# создадим еще директорию
# !mkdir dataset
# Out:
# mkdir: cannot create directory ‘dataset’: File exists

# %% [markdown]
# ###Перемещение файлов в директорию

# %%
# копируем файлы из data в dataset
for filename in file_list:
  shutil.copy('data/'+filename, 'data/'+filename)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-30-dd96ccfe2584> in <cell line: 2>()
#       1 # копируем файлы из data в dataset
#       2 for filename in file_list:
# ----> 3   shutil.copy('data/'+filename, 'data/'+filename)
#
# /usr/lib/python3.10/shutil.py in copy(src, dst, follow_symlinks)
#     415     if os.path.isdir(dst):
#     416         dst = os.path.join(dst, os.path.basename(src))
# --> 417     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418     copymode(src, dst, follow_symlinks=follow_symlinks)
#     419     return dst
#
# /usr/lib/python3.10/shutil.py in copyfile(src, dst, follow_symlinks)
#     252         os.symlink(os.readlink(src), dst)
#     253     else:
# --> 254         with open(src, 'rb') as fsrc:
#     255             try:
#     256                 with open(dst, 'wb') as fdst:
#
# ...

# %%
# посмотрим содержимое папки dataset
print(os.listdir('dataset'))
# Out:
# ['text_7.jpg', 'text_2.jpg', 'text_6.jpg', 'text_3.jpg', 'text_10.jpg', 'text_4.jpg', 'text_9.jpg', 'text_8.jpg', 'text_1.jpg', 'text_5.jpg']

# %%
# посмотрим содержимое папки data
print(os.listdir('data'))
# Out:
# ['text_7.jpg', 'text_2.jpg', 'text_6.jpg', 'text_3.jpg', 'text_10.jpg', 'text_4.jpg', 'text_9.jpg', 'text_8.jpg', 'text_1.jpg', 'text_5.jpg']

# %% [markdown]
# ###Работа с локальным диском. Модуль io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-87698b60-9205-46fd-ad7a-0f65efc7e703" name="files[]" multiple disabled />
#      <output id="result-87698b60-9205-46fd-ad7a-0f65efc7e703">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Text_5+5.zip to Text_5+5 (1).zip

# %%
# создадим еще директорию
# !mkdir data_new

# %%
# !ls
# Out:
# data_new  drive  sample_data  Text_5+5.zip

# %%
# поместим архив в переменную
data = zipfile.ZipFile(io.BytesIO(uploaded['Text_5+5.zip']), 'r')
# посмотрим содержимое переменной с архивом
data.printdir()
# распакуем все в нужную папку
data.extractall('data_new')
data.close()
# Out:
# File Name                                             Modified             Size
# text_4.jpg                                     2019-11-16 05:10:50       132581
# text_6.jpg                                     2019-11-16 05:10:50        65170
# text_8.jpg                                     2019-11-16 05:10:50       108882
# text_5.jpg                                     2019-11-16 05:10:50        61300
# text_2.jpg                                     2019-11-16 05:10:50       132234
# text_9.jpg                                     2019-11-16 05:10:50        82228
# text_7.jpg                                     2019-11-16 05:10:50        87022
# text_10.jpg                                    2019-11-16 05:10:50       106523
# text_1.jpg                                     2019-11-16 05:10:50       162936
# text_3.jpg                                     2019-11-16 05:10:50       143069

# %%
file_list_1 = os.listdir('data_new')

# %%
file_list_1
# Out:
# ['text_4.jpg',
#  'text_7.jpg',
#  'text_3.jpg',
#  'text_8.jpg',
#  'text_10.jpg',
#  'text_1.jpg',
#  'text_2.jpg',
#  'text_9.jpg',
#  'text_6.jpg',
#  'text_5.jpg']

# %%
# еще вариант просмотра содержимого директории
# !ls data_new
# Out:
# text_10.jpg  text_2.jpg  text_4.jpg  text_6.jpg  text_8.jpg
# text_1.jpg   text_3.jpg  text_5.jpg  text_7.jpg  text_9.jpg

# %% [markdown]
# #Colaboratory Content

# %%
# содержание корневой директории Colaboratory
list=os.listdir('/content/')

# %%
list
# Out:
# ['.config', 'data', 'Text_5+5.zip', 'dataset', 'drive', 'sample_data']

# %% [markdown]
# ### Использование os.listdir() и генераторов

# %%
# !ls
# Out:
#  data	    dataset   sample_data	  Text_5+5.zip
#  data_new   drive    'Text_5+5 (1).zip'

# %%
# распакуем архив в корневую директорию Colaboratory
# !unzip Text_5+5.zip
# Out:
# Archive:  Text_5+5.zip
#   inflating: text_4.jpg
#   inflating: text_6.jpg
#   inflating: text_8.jpg
#   inflating: text_5.jpg
#   inflating: text_2.jpg
#   inflating: text_9.jpg
#   inflating: text_7.jpg
#   inflating: text_10.jpg
#   inflating: text_1.jpg
#   inflating: text_3.jpg

# %% [markdown]
# * listdir() возвращает список записей для данного каталога.
# * Метод os.path.isfile() возвращает True, если данная запись является файлом.
# * Оператор yield завершает работу функции, но сохраняя текущее состояние и возвращает только имя записи являющейся файлом.

# %%
# посмотрим на файлы в корневой директории Colaboratory
n = 0 # счетчик файлов
#path = '/content/'
def files(path):
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file
for file in files("."):
    n+=1
    print(file)
print("\nКоличество файлов в корневой директории Colaboratory =", n)
# Out:
# Text_5+5.zip
# text_4.jpg
# text_7.jpg
# text_3.jpg
# text_8.jpg
# text_10.jpg
# text_1.jpg
# Text_5+5 (1).zip
# text_2.jpg
# text_9.jpg
# text_6.jpg
# text_5.jpg
#
# Количество файлов в корневой директории Colaboratory = 12

# %%
# создадим список из файлов
files_in_Colab = []
for file in files("."):
    files_in_Colab.append(file)

# %%
files_in_Colab
# Out:
# ['Text_5+5.zip',
#  'text_4.jpg',
#  'text_7.jpg',
#  'text_3.jpg',
#  'text_8.jpg',
#  'text_10.jpg',
#  'text_1.jpg',
#  'Text_5+5 (1).zip',
#  'text_2.jpg',
#  'text_9.jpg',
#  'text_6.jpg',
#  'text_5.jpg']

# %%
# создадим директорию для перемещения в нее файлов
# !mkdir Files_from_Colab

# %%
# !ls
# Out:
#  data_new	    text_10.jpg   text_4.jpg	      text_6.jpg
#  drive		    text_1.jpg	 'Text_5+5 (1).zip'   text_7.jpg
#  Files_from_Colab   text_2.jpg	  Text_5+5.zip	      text_8.jpg
#  sample_data	    text_3.jpg	  text_5.jpg	      text_9.jpg

# %%
print(os.listdir('Files_from_Colab'))
# Out:
# ['text_4.jpg', 'text_7.jpg', 'text_3.jpg', 'text_8.jpg', 'text_10.jpg', 'text_1.jpg', 'text_2.jpg', 'text_9.jpg', 'text_6.jpg', 'text_5.jpg']

# %%
# подсчитаем количество файлов
# !find /content/Files_from_Colab -type f| wc -l
# Out:
# 10

# %% [markdown]
# ###Посмотрим как работает split

# %%
for filename in files_in_Colab:
  name = filename.split('.')[0]
  print(name)
# Out:
# Text_5+5 (1)
# text_5
# text_9
# text_2
# text_1
# text_6
# text_4
# text_8
# text_3
# Text_5+5
# text_10
# text_7

# %%
for filename in files_in_Colab:
  name = filename.split('.')[1]
  print(name)
# Out:
# zip
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# zip
# jpg
# jpg

# %% [markdown]
# ###КАК РАСПАКОВАТЬ RAR В LINUX
# https://losst.ru/kak-raspakovat-rar-v-linux

# %%
# скопируем файл в Colaboratory
# !cp "/content/drive/My Drive/ИБб-18/Linux/Text_5-5.rar" Text_5-5.rar

# %%
# распаковка архива в корневую директорию Colaboratory
# !unrar e Text_5-5.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Text_5-5.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
# создадим директорию для распаковки архива
# !mkdir RAR

# %%
# распаковка архива в указанную директорию
# !unrar e Text_5-5.rar /content/RAR
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Text_5-5.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
# посмотрим на содержимое директории RAR
# !ls RAR
# Out:
# text_10.jpg  text_2.jpg  text_4.jpg  text_6.jpg  text_8.jpg
# text_1.jpg   text_3.jpg  text_5.jpg  text_7.jpg  text_9.jpg

# %% [markdown]
# #Перемещение папки на Google-диск

# %%
# скопируем архив на гугл диск
# !cp '/content/archive_aug.zip' '/content/drive/My Drive/ИБб-18/Введение в НС/Аугментация данных/Изображения для тиражирования'

# %% [markdown]
# #Перемещение папки на локальный диск

# %%
# скачаем архив на локальный диск
files.download('archive_aug.zip')

# %% [markdown]
# losst.ru/kak-pereimenovat-fajl-linux
#
# #КАК ПЕРЕИМЕНОВАТЬ ФАЙЛ LINUX
